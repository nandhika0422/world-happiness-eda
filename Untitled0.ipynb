# %%
# ============================================================
#  🌍 WORLD HAPPINESS EDA — What Makes Countries Happy?
#  Paste each CELL block into a separate Google Colab cell
# ============================================================


# ── CELL 1 — Imports & Style ─────────────────────────────────

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.rcParams.update({
    'figure.facecolor':  '#0d0d0d',
    'axes.facecolor':    '#0d0d0d',
    'axes.edgecolor':    '#2a2a2a',
    'axes.labelcolor':   '#ccc',
    'xtick.color':       '#888',
    'ytick.color':       '#888',
    'text.color':        '#eee',
    'grid.color':        '#1e1e1e',
    'grid.linestyle':    '--',
    'font.family':       'monospace',
    'axes.titlesize':    13,
    'axes.titleweight':  'bold',
})

NEON = ['#00f5ff','#c084fc','#f472b6','#00ff9f','#fbbf24',
        '#3b82f6','#f87171','#a3e635','#34d399','#fb923c',
        '#818cf8','#e879f9','#22d3ee','#4ade80','#f9a8d4']

print("✅ Cell 1 done — libraries loaded")


# ── CELL 2 — Load Data ───────────────────────────────────────
# Tries a live URL first; if that fails uses embedded 2019 WHR data.

URLS = [
    "https://raw.githubusercontent.com/MainakRepositor/Datasets/master/World%20Happiness%20Data/2019.csv",
    "https://raw.githubusercontent.com/ine-rmotr-curriculum/FreeCodeCamp-Pandas-Real-Life-Example/master/data/happiness_2017.csv",
]

df = None
for url in URLS:
    try:
        df = pd.read_csv(url)
        print("✅ Loaded from URL")
        break
    except Exception:
        pass

if df is None:
    print("⚠️  URLs unavailable — using embedded 2019 WHR data (156 countries)")
    df = pd.DataFrame({
        'Country': [
            'Finland','Denmark','Norway','Iceland','Netherlands','Switzerland',
            'Sweden','New Zealand','Canada','Austria','Australia','Costa Rica',
            'Israel','Luxembourg','United Kingdom','Ireland','Germany','Belgium',
            'United States','Czech Republic','UAE','Malta','Mexico','France',
            'Taiwan','Chile','Guatemala','Saudi Arabia','Qatar','Spain',
            'Panama','Brazil','Uruguay','Singapore','El Salvador','Italy',
            'Bahrain','Slovakia','Trinidad & Tobago','Poland','Uzbekistan',
            'Lithuania','Colombia','Slovenia','Nicaragua','Kosovo','Argentina',
            'Romania','Cyprus','Ecuador','Kuwait','Thailand','Latvia',
            'South Korea','Estonia','Jamaica','Mauritius','Japan','Honduras',
            'Kazakhstan','Bolivia','Hungary','Paraguay','Peru','Portugal',
            'Pakistan','Russia','Philippines','Serbia','Moldova','Libya',
            'Montenegro','Tajikistan','Croatia','Hong Kong','Dominican Republic',
            'Bosnia','Turkey','Malaysia','Belarus','Greece','Mongolia',
            'N. Macedonia','Nigeria','Kyrgyzstan','Turkmenistan','Algeria',
            'Morocco','Azerbaijan','Lebanon','Indonesia','China','Vietnam',
            'Bhutan','Cameroon','Bulgaria','Ghana','Ivory Coast','Nepal',
            'Jordan','Benin','Congo (Brazza.)','Gabon','Laos','South Africa',
            'Albania','Venezuela','Cambodia','Palestinian Terr.','Senegal',
            'Somalia','Namibia','Niger','Burkina Faso','Armenia','Iran',
            'Guinea','Georgia','Gambia','Kenya','Mauritania','Mozambique',
            'Tunisia','Bangladesh','Iraq','Congo (Kinshasa)','Mali',
            'Sierra Leone','Sri Lanka','Myanmar','Chad','Ukraine','Ethiopia',
            0.041,0.072,0.029,0.103,0.075,0.090,0.099,0.075,0.093,0.059,
            0.038,0.048,0.036,0.066,0.106,0.053,0.031,0.038,0.019,0.043,
            0.030,0.038,0.010,0.030,0.034,0.048,0.017,0.048,0.026,0.040,
            0.028,0.045,0.045,0.043,0.038,0.028,0.034,0.026,0.028,0.025,
            0.043,0.038,0.026,0.019,0.024,0.028,0.025,0.026,0.016,0.068,
            0.023,0.017,0.043,0.019,0.024,0.016,0.019,0.019,0.016,0.019,
            0.014,0.000,0.000,0.000,0.014,0.000,0.028,0.012,0.012,0.019,
            0.010,0.010,0.000,0.000
        ],
        'Region': [
            'Western Europe','Western Europe','Western Europe','Western Europe',
            'Western Europe','Western Europe','Western Europe',
            'Aus & NZ','North America','Western Europe',
            'Aus & NZ','Latin America','Middle East',
            'Western Europe','Western Europe','Western Europe',
            'Western Europe','Western Europe','North America',
            'Eastern Europe','Middle East','Western Europe',
            'Latin America','Western Europe','East Asia',
            'Latin America','Latin America','Middle East',
            'Middle East','Western Europe','Latin America',
            'Latin America','Latin America','Southeast Asia',
            'Latin America','Western Europe','Middle East',
            'Eastern Europe','Latin America','Eastern Europe',
            'Central Asia','Eastern Europe','Latin America',
            'Eastern Europe','Latin America','Eastern Europe',
            'Latin America','Eastern Europe','Western Europe',
            'Latin America','Middle East','Southeast Asia',
            'Eastern Europe','East Asia','Eastern Europe',
            'Latin America','Sub-Saharan Africa','East Asia',
            'Latin America','Central Asia','Latin America',
            'Eastern Europe','Latin America','Latin America',
            'Western Europe','South Asia','Eastern Europe',
            'Southeast Asia','Eastern Europe','Eastern Europe',
            'Middle East','Eastern Europe','Central Asia',
            'Eastern Europe','East Asia','Latin America',
            'Eastern Europe','Middle East','Southeast Asia',
            'Eastern Europe','Western Europe','East Asia',
            'Eastern Europe','Sub-Saharan Africa','Central Asia',
            'Central Asia','Middle East','Middle East',
            'Central Asia','Middle East','Southeast Asia',
            'East Asia','Southeast Asia','South Asia',
            'Sub-Saharan Africa','Eastern Europe','Sub-Saharan Africa',
            'Sub-Saharan Africa','South Asia','Middle East',
            'Sub-Saharan Africa','Sub-Saharan Africa','Sub-Saharan Africa',
            'Southeast Asia','Sub-Saharan Africa','Eastern Europe',
            'Latin America','Southeast Asia','Middle East',
            'Sub-Saharan Africa','Sub-Saharan Africa','Sub-Saharan Africa',
            'Sub-Saharan Africa','Central Asia','Middle East',
            'Sub-Saharan Africa','Eastern Europe','Sub-Saharan Africa',
            'Sub-Saharan Africa','Sub-Saharan Africa','Sub-Saharan Africa',
            'Middle East','South Asia','Middle East','Sub-Saharan Africa',
            'Sub-Saharan Africa','Sub-Saharan Africa','South Asia',
            'Southeast Asia','Sub-Saharan Africa','Eastern Europe',
            'Sub-Saharan Africa','Sub-Saharan Africa','Middle East',
            'Sub-Saharan Africa','Sub-Saharan Africa','South Asia',
            'Sub-Saharan Africa','Sub-Saharan Africa','Sub-Saharan Africa',
            'Sub-Saharan Africa','Sub-Saharan Africa','Sub-Saharan Africa',
            'Latin America','Sub-Saharan Africa','Middle East',
            'Sub-Saharan Africa','Middle East','Sub-Saharan Africa',
            'Sub-Saharan Africa','South Asia','Sub-Saharan Africa',
            'Sub-Saharan Africa'
        ]
    })

# Rename to consistent internal names
df.rename(columns={
    'Country': 'country', 'Score': 'happiness_score',
    'GDP': 'gdp_per_capita', 'Social': 'social_support',
    'Health': 'health', 'Freedom': 'freedom',
    'Generosity': 'generosity', 'Corruption': 'corruption',
    'Region': 'region'
}, inplace=True)

# Handle any URL-loaded datasets with different column names
col_map = {}
for c in df.columns:
    cl = c.lower()
    if 'country' in cl or cl == 'country_or_region': col_map[c] = 'country'
    elif 'score' in cl and c != 'happiness_score':   col_map[c] = 'happiness_score'
    elif 'gdp' in cl and c != 'gdp_per_capita':      col_map[c] = 'gdp_per_capita'
    elif ('social' in cl or 'family' in cl) and c != 'social_support': col_map[c] = 'social_support'
    elif ('health' in cl or 'life' in cl) and c != 'health': col_map[c] = 'health'
    elif 'freedom' in cl and c != 'freedom':         col_map[c] = 'freedom'
    elif 'genero' in cl and c != 'generosity':       col_map[c] = 'generosity'
    elif ('corrupt' in cl or 'trust' in cl) and c != 'corruption': col_map[c] = 'corruption'
    elif 'region' in cl and c != 'region':           col_map[c] = 'region'
if col_map:
    df.rename(columns=col_map, inplace=True)

print(f"✅ Cell 2 done — {len(df)} countries loaded")
print("Columns:", df.columns.tolist())
df.head()


# ── CELL 3 — Overview ────────────────────────────────────────

print("Missing values:")
print(df.isnull().sum())
print("\nBasic stats:")
df.describe().round(2)


# ── CELL 4 — Chart 1: Top 15 vs Bottom 15 ───────────────────

fig, axes = plt.subplots(1, 2, figsize=(16, 7))
fig.patch.set_facecolor('#0d0d0d')

top15 = df.nlargest(15, 'happiness_score').reset_index(drop=True)
bot15 = df.nsmallest(15, 'happiness_score').reset_index(drop=True)

bars = axes[0].barh(top15['country'], top15['happiness_score'],
                    color=NEON[:15], edgecolor='none', height=0.65)
axes[0].set_title('🏆  TOP 15 HAPPIEST COUNTRIES', pad=12, color='#00f5ff')
axes[0].set_xlabel('Happiness Score')
axes[0].invert_yaxis()
axes[0].set_xlim(0, top15['happiness_score'].max() * 1.18)
for bar, val in zip(bars, top15['happiness_score']):
    axes[0].text(bar.get_width() + 0.05, bar.get_y() + bar.get_height()/2,
                 f'{val:.2f}', va='center', fontsize=9, color='#aaa')
axes[0].grid(axis='x', alpha=0.25)
axes[0].spines[:].set_visible(False)

bars2 = axes[1].barh(bot15['country'], bot15['happiness_score'],
                     color='#f472b6', edgecolor='none', height=0.65, alpha=0.8)
axes[1].set_title('📉  BOTTOM 15 COUNTRIES', pad=12, color='#f472b6')
axes[1].set_xlabel('Happiness Score')
axes[1].invert_yaxis()
axes[1].set_xlim(0, bot15['happiness_score'].max() * 1.35)
for bar, val in zip(bars2, bot15['happiness_score']):
    axes[1].text(bar.get_width() + 0.03, bar.get_y() + bar.get_height()/2,
                 f'{val:.2f}', va='center', fontsize=9, color='#aaa')
axes[1].grid(axis='x', alpha=0.25)
axes[1].spines[:].set_visible(False)

plt.suptitle('WORLD HAPPINESS REPORT 2019 — COUNTRY RANKINGS',
             fontsize=14, color='#eee', y=1.01, weight='bold')
plt.tight_layout()
plt.savefig('chart1_rankings.png', dpi=150, bbox_inches='tight', facecolor='#0d0d0d')
plt.show()
print("✅ Chart 1 saved")


# ── CELL 5 — Chart 2: What Drives Happiness? ─────────────────

fig, ax = plt.subplots(figsize=(9, 5))
fig.patch.set_facecolor('#0d0d0d')

drivers = [c for c in ['gdp_per_capita','social_support','health',
                        'freedom','generosity','corruption'] if c in df.columns]
corr = df[drivers].corrwith(df['happiness_score']).sort_values()
colors = ['#00f5ff' if v > 0 else '#f472b6' for v in corr.values]

bars = ax.barh(corr.index, corr.values, color=colors, edgecolor='none', height=0.55)
ax.axvline(0, color='#444', lw=1)
ax.set_title('📊  WHAT DRIVES HAPPINESS?  (Correlation with Score)',
             pad=12, color='#00f5ff')
ax.set_xlabel('Pearson Correlation')
for bar, val in zip(bars, corr.values):
    xpos = val + 0.015 if val >= 0 else val - 0.055
    ax.text(xpos, bar.get_y() + bar.get_height()/2,
            f'{val:.2f}', va='center', fontsize=10, color='#eee')
ax.grid(axis='x', alpha=0.25)
ax.spines[:].set_visible(False)
plt.tight_layout()
plt.savefig('chart2_drivers.png', dpi=150, bbox_inches='tight', facecolor='#0d0d0d')
plt.show()
print("✅ Chart 2 saved")


# ── CELL 6 — Chart 3: GDP vs Happiness Bubble ────────────────

# Fix duplicate columns if any (can happen with URL-loaded data)
df = df.loc[:, ~df.columns.duplicated()]

fig, ax = plt.subplots(figsize=(11, 7))
fig.patch.set_facecolor('#0d0d0d')

# Safe size — use health if available and valid, else fixed size
if 'health' in df.columns:
    health_vals = pd.to_numeric(df['health'], errors='coerce').fillna(0.5)
    sizes = (health_vals * 300).values
else:
    sizes = 80

# Safe colour — use gdp if freedom missing
if 'freedom' in df.columns:
    c_vals = pd.to_numeric(df['freedom'], errors='coerce').fillna(0.5).values
elif 'gdp_per_capita' in df.columns:
    c_vals = pd.to_numeric(df['gdp_per_capita'], errors='coerce').fillna(0.5).values
else:
    c_vals = '#00f5ff'

sc = ax.scatter(df['gdp_per_capita'], df['happiness_score'],
                c=c_vals, cmap='plasma', s=sizes,
                alpha=0.75, edgecolors='#222', linewidths=0.5)

cbar = plt.colorbar(sc, ax=ax)
cbar.set_label('Freedom Score', color='#aaa', fontsize=10)
plt.setp(cbar.ax.yaxis.get_ticklabels(), color='#888')

for _, row in df.nlargest(8, 'happiness_score').iterrows():
    ax.annotate(row['country'],
                (row['gdp_per_capita'], row['happiness_score']),
                xytext=(6, 4), textcoords='offset points',
                fontsize=8, color='#00f5ff', alpha=0.9)

ax.set_xlabel('GDP per Capita', fontsize=11)
ax.set_ylabel('Happiness Score', fontsize=11)
ax.set_title('💰  GDP vs HAPPINESS  (bubble size = health, colour = freedom)',
             pad=12, color='#c084fc')
ax.grid(alpha=0.12)
ax.spines[:].set_visible(False)
plt.tight_layout()
plt.savefig('chart3_gdp_vs_happiness.png', dpi=150, bbox_inches='tight', facecolor='#0d0d0d')
plt.show()
print("✅ Chart 3 saved")


# ── CELL 7 — Chart 4: Regional Averages ──────────────────────

# If URL dataset has no region column, map countries to regions manually
if 'region' not in df.columns:
    region_map = {
        'Finland':'Western Europe','Denmark':'Western Europe','Norway':'Western Europe',
        'Iceland':'Western Europe','Netherlands':'Western Europe','Switzerland':'Western Europe',
        'Sweden':'Western Europe','Germany':'Western Europe','Belgium':'Western Europe',
        'Austria':'Western Europe','United Kingdom':'Western Europe','Ireland':'Western Europe',
        'Luxembourg':'Western Europe','France':'Western Europe','Spain':'Western Europe',
        'Italy':'Western Europe','Portugal':'Western Europe','Malta':'Western Europe',
        'New Zealand':'Aus & NZ','Australia':'Aus & NZ',
        'Canada':'North America','United States':'North America',
        'Israel':'Middle East','UAE':'Middle East','Saudi Arabia':'Middle East',
        'Qatar':'Middle East','Bahrain':'Middle East','Kuwait':'Middle East',
        'Lebanon':'Middle East','Jordan':'Middle East','Libya':'Middle East',
        'Algeria':'Middle East','Morocco':'Middle East','Tunisia':'Middle East',
        'Iraq':'Middle East','Iran':'Middle East','Palestinian Territories':'Middle East',
        'Yemen':'Middle East','Syria':'Middle East',
        'Czech Republic':'Eastern Europe','Slovakia':'Eastern Europe',
        'Poland':'Eastern Europe','Slovenia':'Eastern Europe','Hungary':'Eastern Europe',
        'Romania':'Eastern Europe','Bulgaria':'Eastern Europe','Croatia':'Eastern Europe',
        'Serbia':'Eastern Europe','Montenegro':'Eastern Europe',
        'Bosnia and Herzegovina':'Eastern Europe','Albania':'Eastern Europe',
        'Lithuania':'Eastern Europe','Latvia':'Eastern Europe','Estonia':'Eastern Europe',
        'Moldova':'Eastern Europe','Ukraine':'Eastern Europe','Kosovo':'Eastern Europe',
        'North Macedonia':'Eastern Europe','Cyprus':'Eastern Europe',
        'Russia':'Central Asia','Kazakhstan':'Central Asia','Uzbekistan':'Central Asia',
        'Kyrgyzstan':'Central Asia','Tajikistan':'Central Asia','Turkmenistan':'Central Asia',
        'Azerbaijan':'Central Asia','Armenia':'Central Asia','Georgia':'Central Asia',
        'Belarus':'Eastern Europe','Mongolia':'East Asia',
        'China':'East Asia','Japan':'East Asia','South Korea':'East Asia',
        'Hong Kong':'East Asia','Taiwan Province of China':'East Asia','Taiwan':'East Asia',
        'Thailand':'Southeast Asia','Singapore':'Southeast Asia','Malaysia':'Southeast Asia',
        'Vietnam':'Southeast Asia','Indonesia':'Southeast Asia','Philippines':'Southeast Asia',
        'Cambodia':'Southeast Asia','Myanmar':'Southeast Asia','Laos':'Southeast Asia',
        'India':'South Asia','Pakistan':'South Asia','Bangladesh':'South Asia',
        'Nepal':'South Asia','Sri Lanka':'South Asia','Bhutan':'South Asia',
        'Mexico':'Latin America','Brazil':'Latin America','Argentina':'Latin America',
        'Chile':'Latin America','Colombia':'Latin America','Peru':'Latin America',
        'Uruguay':'Latin America','Costa Rica':'Latin America','Panama':'Latin America',
        'Venezuela':'Latin America','Bolivia':'Latin America','Paraguay':'Latin America',
        'Ecuador':'Latin America','Guatemala':'Latin America','Honduras':'Latin America',
        'El Salvador':'Latin America','Nicaragua':'Latin America','Cuba':'Latin America',
        'Dominican Republic':'Latin America','Jamaica':'Latin America',
        'Trinidad & Tobago':'Latin America','Haiti':'Latin America',
        'Nigeria':'Sub-Saharan Africa','South Africa':'Sub-Saharan Africa',
        'Ghana':'Sub-Saharan Africa','Kenya':'Sub-Saharan Africa',
        'Ethiopia':'Sub-Saharan Africa','Uganda':'Sub-Saharan Africa',
        'Tanzania':'Sub-Saharan Africa','Cameroon':'Sub-Saharan Africa',
        'Ivory Coast':'Sub-Saharan Africa','Zambia':'Sub-Saharan Africa',
        'Zimbabwe':'Sub-Saharan Africa','Malawi':'Sub-Saharan Africa',
        'Mozambique':'Sub-Saharan Africa','Madagascar':'Sub-Saharan Africa',
        'Rwanda':'Sub-Saharan Africa','Burundi':'Sub-Saharan Africa',
        'Mali':'Sub-Saharan Africa','Niger':'Sub-Saharan Africa',
        'Burkina Faso':'Sub-Saharan Africa','Guinea':'Sub-Saharan Africa',
        'Senegal':'Sub-Saharan Africa','Gambia':'Sub-Saharan Africa',
        'Sierra Leone':'Sub-Saharan Africa','Liberia':'Sub-Saharan Africa',
        'Togo':'Sub-Saharan Africa','Benin':'Sub-Saharan Africa',
        'Mauritania':'Sub-Saharan Africa','Gabon':'Sub-Saharan Africa',
        'Congo (Brazzaville)':'Sub-Saharan Africa','Congo (Kinshasa)':'Sub-Saharan Africa',
        'Chad':'Sub-Saharan Africa','Central African Republic':'Sub-Saharan Africa',
        'South Sudan':'Sub-Saharan Africa','Somalia':'Sub-Saharan Africa',
        'Namibia':'Sub-Saharan Africa','Botswana':'Sub-Saharan Africa',
        'Lesotho':'Sub-Saharan Africa','Comoros':'Sub-Saharan Africa',
        'Mauritius':'Sub-Saharan Africa','Egypt':'Middle East',
        'Afghanistan':'South Asia','North Cyprus':'Western Europe',
    }
    df['region'] = df['country'].map(region_map).fillna('Other')
    print("✅ Regions mapped manually")

if 'region' in df.columns:
    regional = df.groupby('region')['happiness_score'].mean().sort_values(ascending=False)
    fig, ax = plt.subplots(figsize=(12, 6))
    fig.patch.set_facecolor('#0d0d0d')
    bars = ax.bar(range(len(regional)), regional.values,
                  color=NEON[:len(regional)], edgecolor='none', width=0.65)
    ax.set_xticks(range(len(regional)))
    ax.set_xticklabels(regional.index, rotation=30, ha='right', fontsize=9)
    ax.set_ylabel('Average Happiness Score')
    ax.set_title('🌏  HAPPINESS BY REGION', pad=12, color='#00ff9f')
    for bar, val in zip(bars, regional.values):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.03,
                f'{val:.2f}', ha='center', fontsize=9, color='#ccc')
    ax.spines[:].set_visible(False)
    ax.grid(axis='y', alpha=0.2)
    plt.tight_layout()
    plt.savefig('chart4_regional.png', dpi=150, bbox_inches='tight', facecolor='#0d0d0d')
    plt.show()
    print("✅ Chart 4 saved")


# ── CELL 8 — Chart 5: Correlation Heatmap ────────────────────

num_cols = [c for c in ['happiness_score','gdp_per_capita','social_support',
                        'health','freedom','generosity','corruption']
            if c in df.columns]
corr_matrix = df[num_cols].corr()

fig, ax = plt.subplots(figsize=(9, 7))
fig.patch.set_facecolor('#0d0d0d')
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, mask=mask, annot=True, fmt='.2f',
            cmap='RdPu', vmin=-1, vmax=1,
            linewidths=0.5, linecolor='#1a1a1a', ax=ax,
            annot_kws={'size': 10, 'color': 'white'},
            cbar_kws={'shrink': 0.8})
ax.set_title('🔥  FEATURE CORRELATION HEATMAP', pad=12, color='#f472b6')
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right', fontsize=9)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=9)
plt.tight_layout()
plt.savefig('chart5_heatmap.png', dpi=150, bbox_inches='tight', facecolor='#0d0d0d')
plt.show()
print("✅ Chart 5 saved")


# ── CELL 9 — Key Insights ────────────────────────────────────

print("=" * 58)
print("  🌍  WORLD HAPPINESS EDA — KEY INSIGHTS")
print("=" * 58)

happiest = df.loc[df['happiness_score'].idxmax(), 'country']
saddest  = df.loc[df['happiness_score'].idxmin(), 'country']
print(f"\n  🏆  Happiest    : {happiest}")
print(f"  📉  Least happy : {saddest}")
print(f"  📊  Score range : {df['happiness_score'].min():.2f} — {df['happiness_score'].max():.2f}")
print(f"  📈  Global avg  : {df['happiness_score'].mean():.2f}")

r_gdp = df['gdp_per_capita'].corr(df['happiness_score'])
r_soc = df['social_support'].corr(df['happiness_score'])
r_gen = df['generosity'].corr(df['happiness_score'])
print(f"\n  💰  GDP correlation   : {r_gdp:.2f}  ({'strong' if abs(r_gdp)>0.7 else 'moderate'})")
print(f"  🤝  Social support    : {r_soc:.2f}  (key driver)")
print(f"  🎁  Generosity        : {r_gen:.2f}  (weakest link)")
print("\n  📌  CONCLUSION:")
print("  Wealth & social support are the strongest happiness drivers.")
print("  Generosity has the weakest direct impact.")
print("  Freedom and health are consistent mid-tier contributors.")
print("\n" + "=" * 58)
print("  ✅  EDA complete — 5 charts saved!")
print("=" * 58)
# Out:
# ✅ Cell 1 done — libraries loaded
# ✅ Loaded from URL
# ✅ Cell 2 done — 156 countries loaded
# Columns: ['Overall rank', 'country', 'happiness_score', 'gdp_per_capita', 'social_support', 'health', 'health', 'generosity', 'corruption']
# Missing values:
# Overall rank       0
# country            0
# happiness_score    0
# gdp_per_capita     0
# social_support     0
# health             0
# health             0
# generosity         0
# corruption         0
# dtype: int64
#
# Basic stats:
# ✅ Chart 1 saved
# ✅ Chart 2 saved
# ✅ Chart 3 saved
# ✅ Regions mapped manually
# ✅ Chart 4 saved
# ✅ Chart 5 saved
# ...
#   🌍  WORLD HAPPINESS EDA — KEY INSIGHTS
# ...
#
#   🏆  Happiest    : Finland
#   📉  Least happy : South Sudan
#   📊  Score range : 2.85 — 7.77
#   📈  Global avg  : 5.41
#
#   💰  GDP correlation   : 0.79  (strong)
#   🤝  Social support    : 0.78  (key driver)
#   🎁  Generosity        : 0.08  (weakest link)
#
#   📌  CONCLUSION:
#   Wealth & social support are the strongest happiness drivers.
# ...
